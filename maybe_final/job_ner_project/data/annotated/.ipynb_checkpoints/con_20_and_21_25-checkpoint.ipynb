# %%
import pandas as pd

# 1. Your original 20-JD file
df_20 = pd.read_csv("job_ner_annotations_full_20_jds.csv")

# 2. The new rows you paste into a file, e.g. "job_ner_annotations_jd_21_50.csv"
df_21_50 = pd.read_csv("file_21_25.csv")

# 3. Concatenate
df_all = pd.concat([df_20, df_21_50], ignore_index=True)

# 4. Save combined file
df_all.to_csv("job_ner_annotations_full_25__jds.csv", index=False)
